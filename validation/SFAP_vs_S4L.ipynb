# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
import matplotlib
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 12}

matplotlib.rc('font', **font)

# %%
def getTime():

    nx=500000

    tmin=-3 # In s
    tmax=3 # In s
    time=np.arange(tmin,tmax,(tmax-tmin)/(nx-1))

    return time

# %%
a = np.load('v.npy',allow_pickle=True)
plt.figure()
plt.plot(getTime(),a)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
time = np.linspace(0,2,10000)

# %%
v = np.load('apSundt.npy')

# %%
v.shape
# Out:
# (1000, 6000, 1)

# %%
plt.figure()
plt.plot(v[:,670])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
a = np.load('analytic.npy')
s = np.load('sensing.npy')
plt.figure()
plt.plot(time,a,'-')
plt.plot(time,s,'-')
#plt.xlim([5,10])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
a = np.load('analytic.npy')
s = np.load('sensing.npy')
plt.figure()
plt.plot(time,a,'-')
plt.plot(time,s,'-')
#plt.xlim([5,10])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
a = np.load('analyticSundt.npy')
s = np.load('sensingSundt.npy')
plt.figure()
plt.plot(time[500:],a[500:],'-')
plt.plot(time[500:],s[500:],'-')
#plt.xlim([5,10])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
50e-6/(1.06475e-3-.948250e-3)
# Out:
# 0.42918454935622335

# %%
2000e-6/(.571e-3-.5505e-3)
# Out:
# 97.56097560975606

# %%
2001e-6/(.557750e-3-.537250e-3)
# Out:
# 97.60975609756093

# %%
plt.figure(figsize=(6,5))
plt.subplot(211)
plt.plot(time,a,'-')
plt.plot(time,s,'-')
plt.xlabel('Time (ms)')
plt.ylabel("SFAP (V)")
plt.legend(['Analytic Signal','S4L Sensing'])

plt.subplot(2,1,2)
plt.scatter(a,s)
plt.plot([-6e-7,5e-7],[-6e-7,5e-7],'k')
plt.xlabel('Analytic Signal (V)')
plt.ylabel('S4L Sensing (V)')

plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
from scipy.stats import linregress
linRegress = linregress(a,s)

# %%
linRegress.slope
# Out:
# 0.9833906992440798

# %%
linRegress.intercept
# Out:
# 1.0542961679900626e-09

# %%
linRegress.rvalue**2
# Out:
# 0.9926976360292344

# %%
linRegress.pvalue
# Out:
# 0.0

# %%
np.sum(np.abs(a-s))
# Out:
# 1.1448723170337677e-05

# %%
phi = np.load('phi.npy')
plt.figure()
plt.plot(phi)
# Out:
# <img src="data:image/png;base64,..." width="640">
