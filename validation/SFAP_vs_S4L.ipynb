# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib ipympl

# %%
import matplotlib
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 12}

matplotlib.rc('font', **font)

# %%
def getTime():

    nx=500000

    tmin=-3 # In s
    tmax=3 # In s
    time=np.arange(tmin,tmax,(tmax-tmin)/(nx-1))

    return time

# %%
time = np.linspace(0,2,10000)

# %%
s.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 s.shape
#
# NameError: name 's' is not defined

# %%
v = np.load('apSundt.npy')

# %%
a = np.load(r'D:\vagusNerve\SFAPValidation\analytic.npy')
s = np.load(r'D:\vagusNerve\SFAPValidation\sensing.npy')

# %%
plt.figure(figsize=(6,3))
plt.subplot(121)
plt.plot(time,a,'-')
plt.plot(time,s,'-')
plt.xlabel('Time (ms)')
plt.ylabel("SFAP (V)")
plt.legend(['Analytic Signal','S4L Sensing'])

plt.subplot(122)
plt.scatter(a,s)
plt.plot([-6e-7,5e-7],[-6e-7,5e-7],'k')
plt.xlabel('Analytic\nSignal (V)')
plt.ylabel('S4L Sensing (V)')

plt.tight_layout()
plt.savefig('s4l_validation.png',dpi=600)
# Out:
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# findfont: Font family 'normal' not found.
# ...

# %%
from scipy.stats import linregress
linRegress = linregress(a,s)

# %%
linRegress.slope
# Out:
# 0.9833906992440798

# %%
linRegress.intercept
# Out:
# 1.0542961679900626e-09

# %%
linRegress.rvalue**2
# Out:
# 0.9926976360292344

# %%
linRegress.pvalue
# Out:
# 0.0

# %%
np.sum(np.abs(a-s))
# Out:
# 1.1448723170337677e-05

# %%
phi = np.load('phi.npy')
plt.figure()
plt.plot(phi)
# Out:
# <img src="data:image/png;base64,..." width="640">
