# %%
from vagusNerve.phiShape import *

# %%
recordingDirectory = '/gpfs/bbp.cscs.ch/project/proj85/scratch/vagusNerve/Data/PhiConductivity_Monopolar_Corrected/'

# %%
phi = pd.read_excel(recordingDirectory+str(0)+'_BetterConductivity.xlsx')
phi = phi.iloc[:14000]

# %%
phiShapeEmpirical = (phi.iloc[:,1].values-np.mean(phi.iloc[:,1]))

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.plot(removeZeroCrossings(phiShapeEmpirical))

# %%
xvals, phiShapeEmpirical = editPhiShape(phi,0.06,5e-6)

# %%
plt.figure()
plt.plot(xvals,phiShapeEmpirical)
